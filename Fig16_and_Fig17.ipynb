# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator

# %%
vfosgd_pf_loss = pd.read_csv('DJIA_and_ETTh1_loss_accuracy/DJIA_VFOGD_PF_Loss_MLP.csv')
vfoadam_pf_loss = pd.read_csv('DJIA_and_ETTh1_loss_accuracy/DJIA_VFOAdam_PF_Loss_MLP.csv')

# %%
vfosgd_pf_loss
# Out:
#               Unnamed: 0         0         1         2         3         4  \
# 0  DJIA_VFOGD_PF_06_Loss  4.903883  0.055579  0.047304  0.040065  0.034736
# 1  DJIA_VFOGD_PF_08_Loss  3.037493  0.255563  0.075586  0.039209  0.029130
# 2  DJIA_VFOGD_PF_10_Loss  1.870403  0.126113  0.086127  0.060041  0.044030
# 3  DJIA_VFOGD_PF_12_Loss  2.042427  0.354267  0.076566  0.031227  0.027531
#
#           5         6         7         8  ...       495       496       497  \
# 0  0.030782  0.026940  0.024557  0.022041  ...  0.009654  0.009755  0.009666
# 1  0.024449  0.021783  0.019866  0.018490  ...  0.008511  0.008504  0.008429
# 2  0.033841  0.027322  0.023320  0.020696  ...  0.006353  0.006398  0.006395
# 3  0.025014  0.024210  0.023049  0.022685  ...  0.006087  0.004289  0.006646
#
#         498       499       500       501       502       503       504
# 0  0.009652  0.009699  0.004403  0.043802  0.031717  0.064832  0.995764
# ...

# %%
fig = plt.figure(figsize=(10,6),dpi=300)
plt.rcParams.update({'font.size': 8})
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(vfosgd_pf_loss.iloc[0,1:500],'r--',label=r'$\alpha=0.6$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[1,1:500],'b--',label=r'$\alpha=0.8$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[2,1:500],'y--',label=r'$\alpha=1.0$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[3,1:500],'g-',label=r'$\alpha=1.2$',markersize='1',linewidth ='1')
ax1=plt.gca()
ax1.xaxis.set_major_locator(MultipleLocator(100))
ax1.set_xlim(0,500)
ax1.set_ylim(0.004,0.02)
ax1.set_ylabel(r'$loss$')
ax1.set_title(r'VFOSGD_PF',bbox=dict(facecolor='y', edgecolor='blue', alpha=0.65 ),x=0.5,y=0.7)
ax1.legend()
ax3 = fig.add_subplot(2, 1, 2)
ax3.plot(vfoadam_pf_loss.iloc[0,1:300],'r--',label=r'$\alpha=0.6$',markersize='1',linewidth ='1')
ax3.plot(vfoadam_pf_loss.iloc[1,1:300],'b--',label=r'$\alpha=0.8$',markersize='1',linewidth ='1')
ax3.plot(vfoadam_pf_loss.iloc[2,1:300],'y--',label=r'$\alpha=1.0$',markersize='1',linewidth ='1')
ax3.plot(vfoadam_pf_loss.iloc[3,1:300],'g-',label=r'$\alpha=1.2$',markersize='1',linewidth ='1')
ax3.plot(vfoadam_pf_loss.iloc[4,1:300],'c--',label=r'$\alpha=1.4$',markersize='1',linewidth ='1')
ax3=plt.gca()
ax3.xaxis.set_major_locator(MultipleLocator(50))
ax3.set_xlim(40,300)
ax3.set_ylim(0.003,0.02)
ax3.set_xlabel(r'$epoch$')
ax3.set_ylabel(r'$loss$')
ax3.set_title('VFOAdam_PF',bbox=dict(facecolor='y', edgecolor='blue', alpha=0.65 ),x=0.5,y=0.7)
ax3.legend()
plt.savefig('picture/Fig16.eps',bbox_inches='tight',format='eps')
plt.savefig('picture/Fig16.svg',bbox_inches='tight',format='svg')
plt.savefig('picture/Fig16.pdf',bbox_inches='tight',format='pdf')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
vfosgd_pf_loss = pd.read_csv('DJIA_and_ETTh1_loss_accuracy/ETTh1_VFOGD_PF_Loss_MLP.csv')
vfoadam_pf_loss = pd.read_csv('DJIA_and_ETTh1_loss_accuracy/ETTh1_VFOAdam_PF_Loss_MLP.csv')

# %%
fig = plt.figure(figsize=(10,6),dpi=300)
plt.rcParams.update({'font.size': 8})
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(vfosgd_pf_loss.iloc[0,1:500],'r--',label=r'$\alpha=0.6$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[1,1:500],'b--',label=r'$\alpha=0.8$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[2,1:500],'y--',label=r'$\alpha=1.0$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[3,1:500],'g-',label=r'$\alpha=1.2$',markersize='1',linewidth ='1')
ax1=plt.gca()
ax1.xaxis.set_major_locator(MultipleLocator(50))
ax1.set_xlim(0,500)
ax1.set_ylim(0.5,3)
ax1.set_ylabel(r'$loss$')
ax1.set_title(r'VFOSGD_PF',bbox=dict(facecolor='y', edgecolor='blue', alpha=0.65 ),x=0.5,y=0.7)
ax1.legend()
ax3 = fig.add_subplot(2, 1, 2)
ax3.plot(vfoadam_pf_loss.iloc[0,1:300],'r-',label=r'$\alpha=0.4$',markersize='1',linewidth ='1')
ax3.plot(vfoadam_pf_loss.iloc[1,1:300],'b--',label=r'$\alpha=0.6$',markersize='1',linewidth ='1')
ax3.plot(vfoadam_pf_loss.iloc[2,1:300],'y-',label=r'$\alpha=0.8$',markersize='1',linewidth ='1')
ax3.plot(vfoadam_pf_loss.iloc[3,1:300],'g-',label=r'$\alpha=1.0$',markersize='1',linewidth ='1')
ax3.plot(vfoadam_pf_loss.iloc[4,1:300],'c--',label=r'$\alpha=1.2$',markersize='1',linewidth ='1')
ax3=plt.gca()
ax3.xaxis.set_major_locator(MultipleLocator(25))
ax3.set_xlim(0,300)
ax3.set_ylim(0.75,5)
ax3.set_xlabel(r'$epoch$')
ax3.set_ylabel(r'$loss$')
ax3.set_title('VFOAdam_PF',bbox=dict(facecolor='y', edgecolor='blue', alpha=0.65 ),x=0.5,y=0.5)
ax3.legend()
plt.savefig('picture/Fig17.eps',bbox_inches='tight',format='eps')
plt.savefig('picture/Fig17.svg',bbox_inches='tight',format='svg')
plt.savefig('picture/Fig17.pdf',bbox_inches='tight',format='pdf')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
