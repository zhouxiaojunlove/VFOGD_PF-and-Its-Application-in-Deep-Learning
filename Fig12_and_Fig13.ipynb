# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
#sgd
vfosgd_pf_loss = pd.read_csv('fashion_mnist_loss_accuracy/VFOGD_PF_Loss.csv')
vfosgd_pf_accuracy = pd.read_csv('fashion_mnist_loss_accuracy/VFOGD_PF_Accuracy.csv')
#adam
vfoadam_pf_loss = pd.read_csv('fashion_mnist_loss_accuracy/VFOAdam_PF_Loss.csv')
vfoadam_pf_accuracy = pd.read_csv('fashion_mnist_loss_accuracy/VFOAdam_PF_Accuracy.csv')

# %%
vfosgd_pf_accuracy.iloc[:,1:150]
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.2215  0.5363  0.6983  0.7220  0.7400  0.7439  0.7476  0.7468  0.7655
# 1  0.1863  0.3725  0.6789  0.7208  0.7295  0.7420  0.7461  0.7454  0.7603
# 2  0.1045  0.2325  0.6484  0.7092  0.7261  0.7506  0.7455  0.7620  0.7818
# 3  0.2665  0.5899  0.7088  0.7291  0.7473  0.7635  0.7519  0.7462  0.7704
# 4  0.1871  0.5377  0.6718  0.6929  0.6985  0.7561  0.7772  0.7879  0.7970
# 5  0.7319  0.7807  0.8052  0.7963  0.8316  0.8377  0.8285  0.8455  0.8534
# 6  0.8023  0.8411  0.8497  0.8667  0.8767  0.8796  0.8742  0.8772  0.8818
#
#         9  ...     139     140     141     142     143     144     145  \
# 0  0.7712  ...  0.8820  0.8825  0.8845  0.8860  0.8875  0.8817  0.8812
# 1  0.7667  ...  0.8875  0.8868  0.8866  0.8754  0.8868  0.8829  0.8822
# 2  0.7835  ...  0.8894  0.8780  0.8939  0.8881  0.8887  0.8891  0.8901
# 3  0.7857  ...  0.8852  0.8866  0.8854  0.8886  0.8890  0.8885  0.8898
# ...

# %%
fig = plt.figure(figsize=(10,6),dpi=300)
plt.rcParams.update({'font.size': 8})
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(vfosgd_pf_loss.iloc[0,1:150],'r--',label=r'$\alpha=0.2$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[1,1:150],'b--',label=r'$\alpha=0.4$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[2,1:150],'y--',label=r'$\alpha=0.6$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[3,1:150],'g--',label=r'$\alpha=0.8$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[4,1:150],'c--',label=r'$\alpha=1.0$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[5,1:150],'k-',label=r'$\alpha=1.2$',markersize='1',linewidth ='1')
ax1.plot(vfosgd_pf_loss.iloc[6,1:150],'m-',label=r'$\alpha=1.4$',markersize='1',linewidth ='1')
ax1=plt.gca()
ax1.xaxis.set_major_locator(MultipleLocator(20))
ax1.set_xlim(-1,150)
ax1.set_ylim(0.05,0.7)
#ax1.set_xlabel(r'$epoch$')
ax1.set_ylabel(r'$loss$')
ax1.set_title(r'VFOSGD_PF_Loss',bbox=dict(facecolor='y', edgecolor='blue', alpha=0.65 ),x=0.5,y=0.7)
ax1.legend()
ax2 = fig.add_subplot(2, 1, 2)
ax2.plot(vfosgd_pf_accuracy.iloc[0,1:150],'r--',label=r'$\alpha=0.2$',markersize='1',linewidth ='1')
ax2.plot(vfosgd_pf_accuracy.iloc[1,1:150],'b--',label=r'$\alpha=0.4$',markersize='1',linewidth ='1')
ax2.plot(vfosgd_pf_accuracy.iloc[2,1:150],'y--',label=r'$\alpha=0.6$',markersize='1',linewidth ='1')
ax2.plot(vfosgd_pf_accuracy.iloc[3,1:150],'g--',label=r'$\alpha=0.8$',markersize='1',linewidth ='1')
ax2.plot(vfosgd_pf_accuracy.iloc[4,1:150],'c--',label=r'$\alpha=1.0$',markersize='1',linewidth ='1')
ax2.plot(vfosgd_pf_accuracy.iloc[5,1:150],'k-',label=r'$\alpha=1.2$',markersize='1',linewidth ='1')
ax2.plot(vfosgd_pf_accuracy.iloc[6,1:150],'m-',label=r'$\alpha=1.4$',markersize='1',linewidth ='1')
ax2=plt.gca()
ax2.xaxis.set_major_locator(MultipleLocator(20))
ax2.set_xlim(-1,150)
ax2.set_ylim(0.75,0.91)
ax2.set_xlabel(r'$epoch$')
ax2.set_ylabel(r'$accuracy$')
ax2.set_title(r'VFOSGD_PF_Accuracy',bbox=dict(facecolor='y', edgecolor='blue', alpha=0.65 ),x=0.5,y=0.3)
ax2.legend()
plt.savefig('picture/Fig12.eps',bbox_inches='tight',format='eps')
plt.savefig('picture/Fig12.svg',bbox_inches='tight',format='svg')
plt.savefig('picture/Fig12.pdf',bbox_inches='tight',format='pdf')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
vfosgd_pf_accuracy_02,vfosgd_pf_accuracy_04,vfosgd_pf_accuracy_06,vfosgd_pf_accuracy_08,vfosgd_pf_accuracy_10,vfosgd_pf_accuracy_12,vfosgd_pf_accuracy_14 = 0,0,0,0,0,0,0
for i in range(150):
    vfosgd_pf_accuracy_02 < vfosgd_pf_accuracy.iloc[0,i+1]
    vfosgd_pf_accuracy_02 = vfosgd_pf_accuracy.iloc[0,i+1]
    
    vfosgd_pf_accuracy_04 < vfosgd_pf_accuracy.iloc[1,i+1]
    vfosgd_pf_accuracy_04 = vfosgd_pf_accuracy.iloc[1,i+1]
    
    vfosgd_pf_accuracy_06 < vfosgd_pf_accuracy.iloc[2,i+1]
    vfosgd_pf_accuracy_06 = vfosgd_pf_accuracy.iloc[2,i+1]
    
    vfosgd_pf_accuracy_08 < vfosgd_pf_accuracy.iloc[3,i+1]
    vfosgd_pf_accuracy_08 = vfosgd_pf_accuracy.iloc[3,i+1]
    
    vfosgd_pf_accuracy_10 < vfosgd_pf_accuracy.iloc[4,i+1]
    vfosgd_pf_accuracy_10 = vfosgd_pf_accuracy.iloc[4,i+1]
    
    vfosgd_pf_accuracy_12 < vfosgd_pf_accuracy.iloc[5,i+1]
    vfosgd_pf_accuracy_12 = vfosgd_pf_accuracy.iloc[5,i+1]
    
    vfosgd_pf_accuracy_14 < vfosgd_pf_accuracy.iloc[6,i+1]
    vfosgd_pf_accuracy_14 = vfosgd_pf_accuracy.iloc[6,i+1]

# %%
vfosgd_pf_accuracy_02,vfosgd_pf_accuracy_04,vfosgd_pf_accuracy_06,vfosgd_pf_accuracy_08,vfosgd_pf_accuracy_10,vfosgd_pf_accuracy_12,vfosgd_pf_accuracy_14
# Out:
# (0.8874, 0.8858, 0.8926, 0.8863, 0.8962, 0.8929, 0.8821)

# %%
fig = plt.figure(figsize=(10,6),dpi=300)
plt.rcParams.update({'font.size': 8})
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(vfoadam_pf_loss.iloc[0,1:150],'r--',label=r'$\alpha=0.2$',markersize='1',linewidth ='1')
ax1.plot(vfoadam_pf_loss.iloc[1,1:150],'b--',label=r'$\alpha=0.4$',markersize='1',linewidth ='1')
ax1.plot(vfoadam_pf_loss.iloc[2,1:150],'y-',label=r'$\alpha=0.6$',markersize='1',linewidth ='1')
ax1.plot(vfoadam_pf_loss.iloc[3,1:150],'g-',label=r'$\alpha=0.8$',markersize='1',linewidth ='1')
ax1.plot(vfoadam_pf_loss.iloc[4,1:150],'c--',label=r'$\alpha=1.0$',markersize='1',linewidth ='1')
ax1.plot(vfoadam_pf_loss.iloc[5,1:150],'k--',label=r'$\alpha=1.2$',markersize='1',linewidth ='1')
ax1.plot(vfoadam_pf_loss.iloc[6,1:150],'m--',label=r'$\alpha=1.4$',markersize='1',linewidth ='1')
ax1=plt.gca()
ax1.xaxis.set_major_locator(MultipleLocator(20))
ax1.set_xlim(20,149)
ax1.set_ylim(0.02,0.2)
#ax1.set_xlabel(r'$epoch$')
ax1.set_ylabel(r'$loss$')
ax1.set_title(r'VFOAdam_PF_Loss',bbox=dict(facecolor='y', edgecolor='blue', alpha=0.65 ),x=0.5,y=0.7)
ax1.legend()
ax2 = fig.add_subplot(2, 1, 2)
ax2.plot(vfoadam_pf_accuracy.iloc[0,1:150],'r-',label=r'$\alpha=0.2$',markersize='1',linewidth ='1')
ax2.plot(vfoadam_pf_accuracy.iloc[1,1:150],'b--',label=r'$\alpha=0.4$',markersize='1',linewidth ='1')
ax2.plot(vfoadam_pf_accuracy.iloc[2,1:150],'y--',label=r'$\alpha=0.6$',markersize='1',linewidth ='1')
ax2.plot(vfoadam_pf_accuracy.iloc[3,1:150],'g--',label=r'$\alpha=0.8$',markersize='1',linewidth ='1')
ax2.plot(vfoadam_pf_accuracy.iloc[4,1:150],'c--',label=r'$\alpha=1.0$',markersize='1',linewidth ='1')
ax2.plot(vfoadam_pf_accuracy.iloc[5,1:150],'k--',label=r'$\alpha=1.2$',markersize='1',linewidth ='1')
ax2.plot(vfoadam_pf_accuracy.iloc[6,1:150],'m--',label=r'$\alpha=1.4$',markersize='1',linewidth ='1')
ax2=plt.gca()
ax2.xaxis.set_major_locator(MultipleLocator(5))
ax2.set_xlim(0,40)
ax2.set_ylim(0.80,0.91)
ax2.set_xlabel(r'$epoch$')
ax2.set_ylabel(r'$accuracy$')
ax2.set_title(r'VFOAdam_PF_Accuracy',bbox=dict(facecolor='y', edgecolor='blue', alpha=0.65 ),x=0.5,y=0.3)
ax2.legend()
plt.savefig('picture/Fig13.eps',bbox_inches='tight',format='eps')
plt.savefig('picture/Fig13.svg',bbox_inches='tight',format='svg')
plt.savefig('picture/Fig13.pdf',bbox_inches='tight',format='pdf')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
vfoadam_pf_accuracy_02,vfoadam_pf_accuracy_04,vfoadam_pf_accuracy_06,vfoadam_pf_accuracy_08,vfoadam_pf_accuracy_10,vfoadam_pf_accuracy_12,vfoadam_pf_accuracy_14 = 0,0,0,0,0,0,0
for i in range(150):
    vfoadam_pf_accuracy_02 < vfoadam_pf_accuracy.iloc[0,i+1]
    vfoadam_pf_accuracy_02 = vfoadam_pf_accuracy.iloc[0,i+1]
    
    vfoadam_pf_accuracy_04 < vfoadam_pf_accuracy.iloc[1,i+1]
    vfoadam_pf_accuracy_04 = vfoadam_pf_accuracy.iloc[1,i+1]
    
    vfoadam_pf_accuracy_06 < vfoadam_pf_accuracy.iloc[2,i+1]
    vfoadam_pf_accuracy_06 = vfoadam_pf_accuracy.iloc[2,i+1]
    
    vfoadam_pf_accuracy_08 < vfoadam_pf_accuracy.iloc[3,i+1]
    vfoadam_pf_accuracy_08 = vfoadam_pf_accuracy.iloc[3,i+1]
    
    vfoadam_pf_accuracy_10 < vfoadam_pf_accuracy.iloc[4,i+1]
    vfoadam_pf_accuracy_10 = vfoadam_pf_accuracy.iloc[4,i+1]
    
    vfoadam_pf_accuracy_12 < vfoadam_pf_accuracy.iloc[5,i+1]
    vfoadam_pf_accuracy_12 = vfoadam_pf_accuracy.iloc[5,i+1]
    
    vfoadam_pf_accuracy_14 < vfoadam_pf_accuracy.iloc[6,i+1]
    vfoadam_pf_accuracy_14 = vfoadam_pf_accuracy.iloc[6,i+1]

# %%
vfoadam_pf_accuracy_02,vfoadam_pf_accuracy_04,vfoadam_pf_accuracy_06,vfoadam_pf_accuracy_08,vfoadam_pf_accuracy_10,vfoadam_pf_accuracy_12,vfoadam_pf_accuracy_14
# Out:
# (0.879, 0.8883, 0.8876, 0.8904, 0.8772, 0.8907, 0.8918)
